# %%
#
from qutip import *
from numpy import real, cos, sin, exp, linspace,arccos, array, sqrt,pi
width = 3.45 #W
height = width #H (Or golden ratio)
import numpy as np
#The preamble of the text is:
import matplotlib as mpl
mpl.use('pdf')
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.mlab as mlab

import seaborn as sns
sns.set_context("paper")
sns.set(font_scale=1, style='white')
sns.set_style("ticks", {"xtick.major.size": 2.5, "ytick.major.size": 0, "xtick.direction": "in"})

cmap = sns.color_palette(n_colors=10)
#plt.rc('font', family='serif', serif='Times New Roman')
#plt.rc('font', family='serif', serif='Times New Roman')
#plt.rc('text', usetex=False)
plt.rc('xtick', labelsize=8)
plt.rc('ytick', labelsize=8)
plt.rc('axes', labelsize=8)
import tqdm
from scipy.fft import fft, fftfreq



#
Iz = 0.5*sigmaz()
Ix = 0.5*sigmax()
Iy = 0.5*sigmay()
Ie = qeye(2)*0.5

# %%
def five_pulse_ESEEM(azz, azx, tau1, tau2, Tc, N=1):
    
    U0 = ((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm())*((-1j*WL*Iz*tau1).expm())
    U1 = ((-1j*WL*Iz*tau1).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm())
    W0 = (-1j*WL*Iz*Tc).expm()
    W1 = (-1j*(WL*Iz+azz*Iz+azx*Ix)*Tc).expm()
    V0 = ((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm())*((-1j*WL*Iz*tau2).expm())
    V1 = ((-1j*WL*Iz*tau2).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm())
    
    if N==1:
        tt1 = (V1*W0*U0*(U1.dag())*(W0.dag())*(V0.dag())).tr()
        tt2 = (V0*W0*U0*(U1.dag())*(W0.dag())*(V1.dag())).tr()
        tt3 = (V1*W1*U0*(U1.dag())*(W1.dag())*(V0.dag())).tr()
        tt4 = (V0*W1*U0*(U1.dag())*(W1.dag())*(V1.dag())).tr()
        return [tt1, tt2, tt3, tt4]
    else:
        U0 = (U0**(N%2)) * ((U1*U0)**(N//2))
        U1 = (U1**(N%2)) * ((U0*U1)**(N//2))
        V0 = (V0**(N%2)) * ((V1*V0)**(N//2))
        V1 = (V1**(N%2)) * ((V0*V1)**(N//2))
        tt1 = (V1*W0*U0*(U1.dag())*(W0.dag())*(V0.dag())).tr()
        tt2 = (V0*W0*U0*(U1.dag())*(W0.dag())*(V1.dag())).tr()
        tt3 = (V1*W1*U0*(U1.dag())*(W1.dag())*(V0.dag())).tr()
        tt4 = (V0*W1*U0*(U1.dag())*(W1.dag())*(V1.dag())).tr()
        return [tt1, tt2, tt3, tt4]
############################################################################

def Term1N(azz, azx, tau1, tau2, Tc, N):
    U0 = (((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm())*((-1j*WL*Iz*tau1).expm()))**N
    U1 = (((-1j*WL*Iz*tau1).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm()))**N
    W0 = (-1j*WL*Iz*Tc).expm()
    W1 = (-1j*(WL*Iz+azz*Iz+azx*Ix)*Tc).expm()
    V0 = (((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm())*((-1j*WL*Iz*tau2).expm()))**N
    V1 = (((-1j*WL*Iz*tau2).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm()))**N
    return (V1*W0*U0*(U1.dag())*(W0.dag())*(V0.dag())).tr()

def Term2N(azz, azx, tau1, tau2, Tc, N):
    U0 = (((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm())*((-1j*WL*Iz*tau1).expm()))**N
    U1 = (((-1j*WL*Iz*tau1).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm()))**N
    W0 = (-1j*WL*Iz*Tc).expm()
    W1 = (-1j*(WL*Iz+azz*Iz+azx*Ix)*Tc).expm()
    V0 = (((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm())*((-1j*WL*Iz*tau2).expm()))**N
    V1 = (((-1j*WL*Iz*tau2).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm()))**N
    return (V0*W0*U0*(U1.dag())*(W0.dag())*(V1.dag())).tr()

def Term3N(azz, azx, tau1, tau2, Tc, N):
    U0 = (((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm())*((-1j*WL*Iz*tau1).expm()))**N
    U1 = (((-1j*WL*Iz*tau1).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm()))**N
    W0 = (-1j*WL*Iz*Tc).expm()
    W1 = (-1j*(WL*Iz+azz*Iz+azx*Ix)*Tc).expm()
    V0 = (((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm())*((-1j*WL*Iz*tau2).expm()))**N
    V1 = (((-1j*WL*Iz*tau2).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm()))**N
    return (V1*W1*U0*(U1.dag())*(W1.dag())*(V0.dag())).tr()

def Term4N(azz, azx, tau1, tau2, Tc, N):
    U0 = (((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm())*((-1j*WL*Iz*tau1).expm()))**N
    U1 = (((-1j*WL*Iz*tau1).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau1).expm()))**N
    W0 = (-1j*WL*Iz*Tc).expm()
    W1 = (-1j*(WL*Iz+azz*Iz+azx*Ix)*Tc).expm()
    V0 = (((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm())*((-1j*WL*Iz*tau2).expm()))**N
    V1 = (((-1j*WL*Iz*tau2).expm())*((-1j*(WL*Iz+azz*Iz+azx*Ix)*tau2).expm()))**N
    return (V0*W1*U0*(U1.dag())*(W1.dag())*(V1.dag())).tr()

# %% [markdown]
# # one strong nuclear spin
# I want to see how is the spectrum of one nuclear spin. Then, go to blind spot.

# %%
# determining the parameters
fL = 1.07*60 # kHz
WL = 2*pi*1.07*60 # kHz
Azz = np.array([-204]) # kHz
Azx = np.array([64.4]) # kHz
Fh_up = np.sqrt((fL*np.ones_like(Azz,dtype=float)+Azz)**2+(Azx)**2) # kHz
BS_up = 1/Fh_up # in ms
print('Freq Larmor={} kHz'.format(fL))
print('Azz={} kHz'.format(Azz))
print('Azx={} kHz'.format(Azx))
print('Freq hyp up={} kHz'.format(Fh_up))
print('Blind Spot up={} ms'.format(BS_up))
# Out:
# Freq Larmor=64.2 kHz
# Azz=[-204] kHz
# Azx=[64.4] kHz
# Freq hyp up=[153.92010915] kHz
# Blind Spot up=[0.00649688] ms

# %%
# %matplotlib notebook

start = 1e-3 # in ms
duration = 5 # in ms
steps = 3000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

print('Freq Larmor={} kHz'.format(fL))
print('Azz={} kHz'.format(Azz))
print('Azx={} kHz'.format(Azx))
print('Freq hyp up={} kHz'.format(Fh_up))
print('Blind Spot up={} ms'.format(BS_up))

fig_all,ax_all = plt.subplots(dpi=150)
for tau1 in [0.001, 0.5*BS_up[0], BS_up[0]]:
    tau2=tau1
    term1 = []
    term2 = []
    term3 = []
    term4 = []
    signal = []    
    for tc in tqdm.tqdm_notebook(Tc):
        term1.append(1)
        term2.append(1)
        term3.append(1)
        term4.append(1)
        for i, azz in enumerate(Azz):
            terms= five_pulse_ESEEM(2*pi*azz, 2*pi*Azx[i], tau1, tau2, tc)
            term1[-1] *= terms[0]
            term2[-1] *= terms[1]
            term3[-1] *= terms[2]
            term4[-1] *= terms[3]
        signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)

    fig,ax = plt.subplots(dpi=150)
    plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
    ax.plot(1000*Tc, signal,'-o',markersize=2, alpha = 1)
    ax.set_xlabel(r'$T_c$ [$\mu s$]')
    ax.set_ylabel(r'signal')
    plt.tight_layout()

    fig,ax = plt.subplots(dpi=150)
    plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
    ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
    ax_all.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha=1,
                label=r'$\tau_1$={},'.format(1e-7*(round(tau1*1e7)))+r' $\tau_2$={} [$\mu s$]'.format(1e-7*(round(tau2*1e7))) )
    ax.set_xlabel('Frequency [kHz]')
    ax.set_ylabel('FFT of signal')
    
ax_all.set_xlabel(r'$\omega$ [kHz]')
ax_all.set_ylabel('FFT of signal')
ax_all.legend()
# Out:
# Freq Larmor=64.2 kHz
# Azz=[-204] kHz
# Azx=[64.4] kHz
# Freq hyp up=[153.92010915] kHz
# Blind Spot up=[0.00649688] ms
# <img src="data:image/png;base64,..." width="900">
# C:\Users\User\AppData\Local\Temp/ipykernel_26692/736734545.py:23: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for tc in tqdm.tqdm_notebook(Tc):
#   0%|          | 0/3000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">
# C:\Users\User\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# <img src="data:image/png;base64,..." width="900">
# C:\Users\User\AppData\Local\Temp/ipykernel_26692/736734545.py:23: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %% [markdown]
# Signal consist of four terms. Let's see how each of them behave

# %%
# %matplotlib notebook

start = 1e-3 # in ms
duration = 5 # in ms
steps = 3000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

print('Freq Larmor={} kHz'.format(fL))
print('Azz={} kHz'.format(Azz))
print('Azx={} kHz'.format(Azx))
print('Freq hyp up={} kHz'.format(Fh_up))
print('Blind Spot up={} ms'.format(BS_up))

for tau1 in [0.001, 0.5*BS_up[0], BS_up[0]]:
    tau2=tau1
    term1 = []
    term2 = []
    term3 = []
    term4 = []
    signal = []    
    for tc in tqdm.tqdm_notebook(Tc):
        term1.append(1)
        term2.append(1)
        term3.append(1)
        term4.append(1)
        for i, azz in enumerate(Azz):
            terms= five_pulse_ESEEM(2*pi*azz, 2*pi*Azx[i], tau1, tau2, tc)
            term1[-1] *= terms[0]
            term2[-1] *= terms[1]
            term3[-1] *= terms[2]
            term4[-1] *= terms[3]
        signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)

    fig,ax = plt.subplots(dpi=150)
    plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
    ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term1[0]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
           label="term1")
    ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term2[0]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
           label="term2")
    ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term3[0]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
           label="term3")
    ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term4[0]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
           label="term4")
    ax.set_xlabel('Frequency [kHz]')
    ax.set_ylabel('FFT of signal')

    fig,ax = plt.subplots(dpi=150)
    plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
    ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
           label="signal")
    ax.set_xlabel('Frequency [kHz]')
    ax.set_ylabel('FFT of signal')
# Out:
# Freq Larmor=64.2 kHz
# Azz=[-204] kHz
# Azx=[64.4] kHz
# Freq hyp up=[153.92010915] kHz
# Blind Spot up=[0.00649688] ms
# C:\Users\User\AppData\Local\Temp/ipykernel_26692/1573490825.py:22: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for tc in tqdm.tqdm_notebook(Tc):
#   0%|          | 0/3000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26692/1573490825.py in <module>
#      35     fig,ax = plt.subplots(dpi=150)
#      36     plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
# ---> 37     ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term1[0]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
#      38            label="term1")
# ...

# %%
fig,ax = plt.subplots(dpi=150)
plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term1[-1]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,label="term1")
ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term2[0]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
       label="term2")
ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term3[0]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
       label="term3")
ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term4[0]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
       label="term4")
ax.set_xlabel('Frequency [kHz]')
ax.set_ylabel('FFT of signal')
# Out:
# <img src="data:image/png;base64,..." width="900">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26692/2313997741.py in <module>
#       1 fig,ax = plt.subplots(dpi=150)
#       2 plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
# ----> 3 ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term1[-1]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,label="term1")
#       4 ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(term2[0]))[0:int(steps/2)],'-o',markersize=2, alpha = 1,
#       5        label="term2")
#
# ~\anaconda3\lib\site-packages\scipy\fft\_backend.py in __ua_function__(method, args, kwargs)
#      21         if fn is None:
#      22             return NotImplemented
# ---> 23         return fn(*args, **kwargs)
#      24
#      25
#
# ...

# %% [markdown]
# # Two strong nuclear spins
# How the spectrum is. Can we go to blind spot of both?

# %%
# determining the parameters
WL =2*pi* 1.07*60 # kHz
Azz = 2*pi* np.array([-204, 51.5]) # kHz
Azx = 2*pi*np.array([64.4, 143.6]) # kHz
omega_up = np.sqrt((WL*np.ones_like(Azz,dtype=float)+Azz)**2+(Azx)**2) # kHz
BS_up = 2*pi/omega_up
print(WL, Azz, Azx,omega_up,BS_up)
# Out:
# 403.38049672092944 [-1281.76980266   323.58404332] [404.63713378 902.26541011] [ 967.10856828 1158.68904921] [0.00649688 0.00542267]

# %%
# %matplotlib notebook

start = 1e-3 # in ms
duration = 5 # in ms
steps = 1000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

print(r'$\omega_L$={}'.format(WL))
print('Azz={}'.format(Azz))
print('Azx={}'.format(Azx))
print('omega_up={}'.format(omega_up))
print('BlindSpot_up={}'.format(BS_up))

fig_all,ax_all = plt.subplots(dpi=150)
for tau1, tau2 in [[0.006,0.006], [0.5*BS_up[0],BS_up[1]],[BS_up[0],0.5*BS_up[1]] , [BS_up[0],BS_up[1]]]:
    term1 = []
    term2 = []
    term3 = []
    term4 = []
    signal = []    
    for tc in tqdm.notebook.tqdm(Tc):
        term1.append(1)
        term2.append(1)
        term3.append(1)
        term4.append(1)
        for i, azz in enumerate(Azz):
            terms= five_pulse_ESEEM(azz, Azx[i], tau1, tau2, tc)
            term1[-1] *= terms[0]
            term2[-1] *= terms[1]
            term3[-1] *= terms[2]
            term4[-1] *= terms[3]
        signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


    fig,ax = plt.subplots(dpi=150)
    plt.title(r'$\tau_1$={},'.format(1e-7*(round(tau1*1e7)))+r' $\tau_2$={} [$\mu s$]'.format(1e-7*(round(tau2*1e7))))
    ax.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],
            '-o',markersize=2, alpha = 1)
    ax_all.plot(fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2,
                alpha = 1, label=r'$\tau_1$={},'.format(1e-7*(round(tau1*1e7)))+r' $\tau_2$={} [$\mu s$]'.format(1e-7*(round(tau2*1e7))) )
    ax.set_xlabel(r'$\omega$ [kHz]')
    ax.set_ylabel('FFT of signal')
    
ax_all.set_xlabel(r'$\omega$ [kHz]')
ax_all.set_ylabel('FFT of signal')
ax_all.legend()
# Out:
# $\omega_L$=403.38049672092944
# Azz=[-1281.76980266   323.58404332]
# Azx=[404.63713378 902.26541011]
# omega_up=[ 967.10856828 1158.68904921]
# BlindSpot_up=[0.00649688 0.00542267]
# <img src="data:image/png;base64,..." width="900">
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Three nuclear spins (Two strong + one week)

# %%
round(7.9)
# Out:
# 8

# %%
# determining the parameters
WL = 2*pi*2800*90*1e-4 # kHz
Azz = np.array([2*pi*18.8, 2*pi*31, 2*pi*1.6]) # kHz
Azx = np.array([2*pi*20, 2*pi*15, 2*pi*2.4]) # kHz
omega_up = np.sqrt((WL*np.ones_like(Azz,dtype=float)+Azz)**2+(Azx)**2) # kHz
BlindSpot_up = 2*pi/omega_up # in ms
print(WL, Azz, Azx,omega_up,BlindSpot_up)
# Out:
# 158.3362697409256 [118.12388377 194.77874452  10.05309649] [125.66370614  94.24777961  15.07964474] [303.68006771 365.47620615 169.06322588] [0.02069015 0.01719178 0.03716471]

# %%
# %matplotlib notebook
tau1 = 1e-3 # in ms
tau2 = 1e-3 # in ms
start = 1e-3 # in ms
duration = 5 # in ms
steps = 1000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

for tau1 in [0.006, 0.02069015]:
    for tau2 in [0.006, 0.01719178]:
        term1 = []
        term2 = []
        term3 = []
        term4 = []
        signal = []    
        for tc in tqdm.notebook.tqdm(Tc):

            term1.append(1)
            term2.append(1)
            term3.append(1)
            term4.append(1)
            for i, azz in enumerate(Azz):
                term1[-1] *= Term1(azz, Azx[i], tau1, tau2, tc)
                term2[-1] *= Term2(azz, Azx[i], tau1, tau2, tc)
                term3[-1] *= Term3(azz, Azx[i], tau1, tau2, tc)
                term4[-1] *= Term4(azz, Azx[i], tau1, tau2, tc)
            signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


        fig,ax = plt.subplots(dpi=150)
        plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
        ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
        ax.set_xlabel(r'$\omega$ [kHz]')
        ax.set_ylabel('FFT of signal')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="432">
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="432">
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="432">
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # 10 nuclear spin (2 strong + 8 weak)

# %%
# determining the parameters
WL = 2*pi*2800*90*1e-4 # kHz
Azz = np.array([2*pi*18.8, 2*pi*31, 2*pi*1.6]) # kHz
Azx = np.array([2*pi*20, 2*pi*15, 2*pi*2.4]) # kHz

rand_Azz = np.random.normal(loc=0, scale=2, size=7)
rand_Azx = np.random.normal(loc=0, scale=2, size=7)
Azz = np.append(Azz, rand_Azz)
Azx = np.append(Azx, rand_Azx)

omega_up = np.sqrt((WL*np.ones_like(Azz,dtype=float)+Azz)**2+(Azx)**2) # kHz
BlindSpot_up = 2*pi/omega_up # in ms
print(r'$\omega_L$={}'.format(WL))
print('Azz={}'.format(Azz))
print('Azx={}'.format(Azx))
print('omega_up={}'.format(omega_up))
print('BlindSpot_up={}'.format(BlindSpot_up))
# Out:
# $\omega_L$=158.3362697409256
# Azz=[118.12388377 194.77874452  10.05309649  -2.97476116   0.72846584
#    4.23424276   1.65803263  -3.12612372   1.01846571   1.61264446]
# Azx=[125.66370614  94.24777961  15.07964474  -4.38530659  -1.7920388
#   -1.31592229  -1.73825288  -1.71799438  -0.84408179  -1.3411477 ]
# omega_up=[303.68006771 365.47620615 169.06322588 155.42338711 159.0748299
#  162.57583826 160.00374468 155.21965382 159.35697093 159.95453676]
# BlindSpot_up=[0.02069015 0.01719178 0.03716471 0.04042625 0.0394983  0.03864772
#  0.03926899 0.04047932 0.03942837 0.03928107]

# %%
# %matplotlib notebook
tau1 = 1e-3 # in ms
tau2 = 1e-3 # in ms
start = 1e-3 # in ms
duration = 5 # in ms
steps = 1000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

for tau1 in [0.02069015]:
    for tau2 in [0.01719178]:
        term1 = []
        term2 = []
        term3 = []
        term4 = []
        signal = []    
        for tc in tqdm.notebook.tqdm(Tc):

            term1.append(1)
            term2.append(1)
            term3.append(1)
            term4.append(1)
            for i, azz in enumerate(Azz):
                term1[-1] *= Term1(azz, Azx[i], tau1, tau2, tc)
                term2[-1] *= Term2(azz, Azx[i], tau1, tau2, tc)
                term3[-1] *= Term3(azz, Azx[i], tau1, tau2, tc)
                term4[-1] *= Term4(azz, Azx[i], tau1, tau2, tc)
            signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


        fig,ax = plt.subplots(dpi=150)
        plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
        ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
        ax.set_xlabel(r'$\omega$ [kHz]')
        ax.set_ylabel('FFT of signal')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">

# %%
# determining the parameters
WL = 2*pi*2800*90*1e-4 # kHz
Azz = np.array([2*pi*18.8, 2*pi*31]) # kHz
Azx = np.array([2*pi*20, 2*pi*15]) # kHz

rand_Azz = np.random.normal(loc=0, scale=10, size=8)
rand_Azx = np.random.normal(loc=0, scale=10, size=8)
Azz = np.append(Azz, rand_Azz)
Azx = np.append(Azx, rand_Azx)

omega_up = np.sqrt((WL*np.ones_like(Azz,dtype=float)+Azz)**2+(Azx)**2) # kHz
BlindSpot_up = 2*pi/omega_up # in ms
print(r'$\omega_L$={}'.format(WL))
print('Azz={}'.format(Azz))
print('Azx={}'.format(Azx))
print('omega_up={}'.format(omega_up))
print('BlindSpot_up={}'.format(BlindSpot_up))
# Out:
# $\omega_L$=158.3362697409256
# Azz=[118.12388377 194.77874452  32.8664595    0.6902376   11.86538156
#   12.02303555  -8.60631981  15.18314016  -6.49064931  -5.23071975]
# Azx=[ 1.25663706e+02  9.42477796e+01 -1.46229996e+01 -8.82815857e+00
#   1.17369043e+01  8.74088438e+00 -1.21078283e-01  4.28039159e+00
#   1.28300187e+01 -4.70499350e+00]
# omega_up=[303.68006771 365.47620615 191.76109039 159.27136096 170.60585285
#  170.58339884 149.72999889 173.5721964  152.38668519 153.17782607]
# BlindSpot_up=[0.02069015 0.01719178 0.03276569 0.03944956 0.03682866 0.03683351
#  0.04196344 0.03619926 0.04123185 0.0410189 ]

# %%
# %matplotlib notebook
tau1 = 1e-3 # in ms
tau2 = 1e-3 # in ms
start = 1e-3 # in ms
duration = 20 # in ms
steps = 10000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

for tau1 in [0.02069015]:
    for tau2 in [0.01719178]:
        term1 = []
        term2 = []
        term3 = []
        term4 = []
        signal = []    
        for tc in tqdm.notebook.tqdm(Tc):

            term1.append(1)
            term2.append(1)
            term3.append(1)
            term4.append(1)
            for i, azz in enumerate(Azz):
                term1[-1] *= Term1(azz, Azx[i], tau1, tau2, tc)
                term2[-1] *= Term2(azz, Azx[i], tau1, tau2, tc)
                term3[-1] *= Term3(azz, Azx[i], tau1, tau2, tc)
                term4[-1] *= Term4(azz, Azx[i], tau1, tau2, tc)
            signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


        fig,ax = plt.subplots(dpi=150)
        plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
        ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
        ax.set_xlabel(r'$\omega$ [kHz]')
        ax.set_ylabel('FFT of signal')
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">

# %%
# %matplotlib notebook
tau1 = 1e-3 # in ms
tau2 = 1e-3 # in ms
start = 1e-3 # in ms
duration = 20 # in ms
steps = 10000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz
Azz=np.array([118.12388377, 194.77874452,  32.8664595 ,   0.6902376,   11.86538156,
  12.02303555,  -8.60631981,  15.18314016,  -6.49064931,  -5.23071975])
Azx=np.array([ 1.25663706e+02,  9.42477796e+01, -1.46229996e+01, -8.82815857e+00,
  1.17369043e+01,  8.74088438e+00 ,-1.21078283e-01,  4.28039159e+00,
  1.28300187e+01, -4.70499350e+00])
omega_up = np.sqrt((WL*np.ones_like(Azz,dtype=float)+Azz)**2+(Azx)**2) # kHz
BlindSpot_up = 2*pi/omega_up # in ms
print(r'$\omega_L$={}'.format(WL))
print('Azz={}'.format(Azz))
print('Azx={}'.format(Azx))
print('omega_up={}'.format(omega_up))
print('BlindSpot_up={}'.format(BlindSpot_up))

for tau1 in [0.02069015*6]:
    for tau2 in [0.01719178*6]:
        term1 = []
        term2 = []
        term3 = []
        term4 = []
        signal = []    
        for tc in tqdm.notebook.tqdm(Tc):

            term1.append(1)
            term2.append(1)
            term3.append(1)
            term4.append(1)
            for i, azz in enumerate(Azz):
                term1[-1] *= Term1(azz, Azx[i], tau1, tau2, tc)
                term2[-1] *= Term2(azz, Azx[i], tau1, tau2, tc)
                term3[-1] *= Term3(azz, Azx[i], tau1, tau2, tc)
                term4[-1] *= Term4(azz, Azx[i], tau1, tau2, tc)
            signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


        fig,ax = plt.subplots(dpi=150)
        plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
        ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
        ax.set_xlabel(r'$\omega$ [kHz]')
        ax.set_ylabel('FFT of signal')
# Out:
# $\omega_L$=158.3362697409256
# Azz=[118.12388377 194.77874452  32.8664595    0.6902376   11.86538156
#   12.02303555  -8.60631981  15.18314016  -6.49064931  -5.23071975]
# Azx=[ 1.25663706e+02  9.42477796e+01 -1.46229996e+01 -8.82815857e+00
#   1.17369043e+01  8.74088438e+00 -1.21078283e-01  4.28039159e+00
#   1.28300187e+01 -4.70499350e+00]
# omega_up=[303.68006765 365.47620614 191.76109039 159.27136096 170.60585285
#  170.58339884 149.72999889 173.5721964  152.38668519 153.17782608]
# BlindSpot_up=[0.02069015 0.01719178 0.03276569 0.03944956 0.03682866 0.03683351
#  0.04196344 0.03619926 0.04123185 0.0410189 ]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">

# %%
fig,ax = plt.subplots(dpi=150)
plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
ax.set_yscale('log')
ax.set_xlabel(r'$\omega$ [kHz]')
ax.set_ylabel('FFT of signal')
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0, 0.5, 'FFT of signal')

# %% [markdown]
# # 4 nuclear spins, higher order blind spots: sounds great at even values

# %%
# determining the parameters
WL = 2*pi*2800*90*1e-4 # kHz
Azz = np.array([2*pi*18.8, 2*pi*31, 2*pi*3.6, 2*pi*1 ]) # kHz
Azx = np.array([2*pi*20, 2*pi*15, 2*pi*2.4, 2*pi*0.5]) # kHz

omega_up = np.sqrt((WL*np.ones_like(Azz,dtype=float)+Azz)**2+(Azx)**2) # kHz
BlindSpot_up = 2*pi/omega_up # in ms
print(r'$\omega_L$={}'.format(WL))
print('Azz={}'.format(Azz))
print('Azx={}'.format(Azx))
print('omega_up={}'.format(omega_up))
print('BlindSpot_up={}'.format(BlindSpot_up))
# Out:
# $\omega_L$=158.3362697409256
# Azz=[118.12388377 194.77874452  22.61946711   6.28318531]
# Azx=[125.66370614  94.24777961  15.07964474   3.14159265]
# omega_up=[303.68006771 365.47620615 181.58296832 164.64942935]
# BlindSpot_up=[0.02069015 0.01719178 0.03460228 0.03816099]

# %%
# %matplotlib notebook
start = 1e-3 # in ms
duration = 5 # in ms
steps = 1000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

for tau1 in [0.02069015]:
    for tau2 in [0.01719178]:
        term1 = []
        term2 = []
        term3 = []
        term4 = []
        signal = []    
        for tc in tqdm.notebook.tqdm(Tc):

            term1.append(1)
            term2.append(1)
            term3.append(1)
            term4.append(1)
            for i, azz in enumerate(Azz):
                term1[-1] *= Term1(azz, Azx[i], tau1, tau2, tc)
                term2[-1] *= Term2(azz, Azx[i], tau1, tau2, tc)
                term3[-1] *= Term3(azz, Azx[i], tau1, tau2, tc)
                term4[-1] *= Term4(azz, Azx[i], tau1, tau2, tc)
            signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


        fig,ax = plt.subplots(dpi=150)
        plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
        ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
        ax.set_yscale('log')
        ax.set_xlabel(r'$\omega$ [kHz]')
        ax.set_ylabel('FFT of signal')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">

# %%
# %matplotlib notebook
start = 1e-3 # in ms
duration = 5 # in ms
steps = 1000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz
print(r'$\omega_L$={}'.format(WL))
print('Azz={}'.format(Azz))
print('Azx={}'.format(Azx))
print('omega_up={}'.format(omega_up))
print('BlindSpot_up={}'.format(BlindSpot_up))
for tau1 in [0.01719178*2]:
    for tau2 in [0.02069015*2]:
        term1 = []
        term2 = []
        term3 = []
        term4 = []
        signal = []    
        for tc in tqdm.notebook.tqdm(Tc):

            term1.append(1)
            term2.append(1)
            term3.append(1)
            term4.append(1)
            for i, azz in enumerate(Azz):
                term1[-1] *= Term1(azz, Azx[i], tau1, tau2, tc)
                term2[-1] *= Term2(azz, Azx[i], tau1, tau2, tc)
                term3[-1] *= Term3(azz, Azx[i], tau1, tau2, tc)
                term4[-1] *= Term4(azz, Azx[i], tau1, tau2, tc)
            signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


        fig,ax = plt.subplots(dpi=150)
        plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
        ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
        ax.set_yscale('log')
        ax.set_xlim(left=140, right=390)
        ax.set_xlabel(r'$\omega$ [kHz]')
        ax.set_ylabel('FFT of signal')
# Out:
# $\omega_L$=158.3362697409256
# Azz=[118.12388377 194.77874452  22.61946711   6.28318531]
# Azx=[125.66370614  94.24777961  15.07964474   3.14159265]
# omega_up=[303.68006771 365.47620615 181.58296832 164.64942935]
# BlindSpot_up=[0.02069015 0.01719178 0.03460228 0.03816099]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # 4 Nuclear spin, increasing pi pulses

# %%
# %matplotlib notebook
start = 1e-3 # in ms
duration = 5 # in ms
steps = 1000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

print(r'$\omega_L$={}'.format(WL))
print('Azz={}'.format(Azz))
print('Azx={}'.format(Azx))
print('omega_up={}'.format(omega_up))
print('BlindSpot_up={}'.format(BlindSpot_up))

pulse_power = 2
for tau1 in [0.01719178]:
    for tau2 in [0.02069015]:
        term1 = []
        term2 = []
        term3 = []
        term4 = []
        signal = []    
        for tc in tqdm.notebook.tqdm(Tc):

            term1.append(1)
            term2.append(1)
            term3.append(1)
            term4.append(1)
            for i, azz in enumerate(Azz):
                term1[-1] *= Term1N(azz, Azx[i], tau1, tau2, tc, pulse_power)
                term2[-1] *= Term2N(azz, Azx[i], tau1, tau2, tc, pulse_power)
                term3[-1] *= Term3N(azz, Azx[i], tau1, tau2, tc, pulse_power)
                term4[-1] *= Term4N(azz, Azx[i], tau1, tau2, tc, pulse_power)
            signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


        fig,ax = plt.subplots(dpi=150)
        plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
        ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
        ax.set_yscale('log')
        ax.set_xlim(left=140, right=390)
        ax.set_xlabel(r'$\omega$ [kHz]')
        ax.set_ylabel('FFT of signal')
# Out:
# $\omega_L$=158.3362697409256
# Azz=[118.12388377 194.77874452  22.61946711   6.28318531]
# Azx=[125.66370614  94.24777961  15.07964474   3.14159265]
# omega_up=[303.68006771 365.47620615 181.58296832 164.64942935]
# BlindSpot_up=[0.02069015 0.01719178 0.03460228 0.03816099]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">

# %%
# %matplotlib notebook
start = 1e-3 # in ms
duration = 5 # in ms
steps = 1000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

print(r'$\omega_L$={}'.format(WL))
print('Azz={}'.format(Azz))
print('Azx={}'.format(Azx))
print('omega_up={}'.format(omega_up))
print('BlindSpot_up={}'.format(BlindSpot_up))

pulse_power = 5
for tau1 in [(0.01719178*6+0.02069015*5)/2]:
    for tau2 in [1.5*0.03816099]:
        term1 = []
        term2 = []
        term3 = []
        term4 = []
        signal = []    
        for tc in tqdm.notebook.tqdm(Tc):

            term1.append(1)
            term2.append(1)
            term3.append(1)
            term4.append(1)
            for i, azz in enumerate(Azz):
                term1[-1] *= Term1N(azz, Azx[i], tau1, tau2, tc, pulse_power)
                term2[-1] *= Term2N(azz, Azx[i], tau1, tau2, tc, pulse_power)
                term3[-1] *= Term3N(azz, Azx[i], tau1, tau2, tc, pulse_power)
                term4[-1] *= Term4N(azz, Azx[i], tau1, tau2, tc, pulse_power)
            signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


        fig,ax = plt.subplots(dpi=150)
        plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
        ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
        ax.set_yscale('log')
        ax.set_xlim(left=140, right=390)
        ax.set_xlabel(r'$\omega$ [kHz]')
        ax.set_ylabel('FFT of signal')
# Out:
# $\omega_L$=158.3362697409256
# Azz=[118.12388377 194.77874452  22.61946711   6.28318531]
# Azx=[125.66370614  94.24777961  15.07964474   3.14159265]
# omega_up=[303.68006771 365.47620615 181.58296832 164.64942935]
# BlindSpot_up=[0.02069015 0.01719178 0.03460228 0.03816099]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">

# %%
# %matplotlib notebook
start = 1e-3 # in ms
duration = 5 # in ms
steps = 1000
Tc = linspace(start,start+duration, steps) # in us
sample_rate = steps/duration # in kHz

print(r'$\omega_L$={}'.format(WL))
print('Azz={}'.format(Azz))
print('Azx={}'.format(Azx))
print('omega_up={}'.format(omega_up))
print('BlindSpot_up={}'.format(BlindSpot_up))

pulse_power = 5
for tau1 in [(0.01719178*6+0.02069015*5)/2]:
    for tau2 in [0.5*0.03460228 ]:
        term1 = []
        term2 = []
        term3 = []
        term4 = []
        signal = []    
        for tc in tqdm.notebook.tqdm(Tc):

            term1.append(1)
            term2.append(1)
            term3.append(1)
            term4.append(1)
            for i, azz in enumerate(Azz):
                term1[-1] *= Term1N(azz, Azx[i], tau1, tau2, tc, pulse_power)
                term2[-1] *= Term2N(azz, Azx[i], tau1, tau2, tc, pulse_power)
                term3[-1] *= Term3N(azz, Azx[i], tau1, tau2, tc, pulse_power)
                term4[-1] *= Term4N(azz, Azx[i], tau1, tau2, tc, pulse_power)
            signal.append((term1[-1] - term2[-1] + term3[-1] - term4[-1])/4)


        fig,ax = plt.subplots(dpi=150)
        plt.title(r'$\tau_1$={},'.format(tau1)+r' $\tau_2$={} [$\mu s$]'.format(tau2))
        ax.plot(2*np.pi*fftfreq(steps, 1/sample_rate)[0:int(steps/2)], np.abs(fft(signal))[0:int(steps/2)],'-o',markersize=2, alpha = 1)
        ax.set_yscale('log')
        ax.set_xlim(left=140, right=390)
        ax.set_xlabel(r'$\omega$ [kHz]')
        ax.set_ylabel('FFT of signal')
# Out:
# $\omega_L$=158.3362697409256
# Azz=[118.12388377 194.77874452  22.61946711   6.28318531]
# Azx=[125.66370614  94.24777961  15.07964474   3.14159265]
# omega_up=[303.68006771 365.47620615 181.58296832 164.64942935]
# BlindSpot_up=[0.02069015 0.01719178 0.03460228 0.03816099]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="900">

# %%
for i in [1,2,3]:
    [t, tt, ttt] *= np.array([1,2,3])
    print(t,tt,ttt)
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_32232/1519617191.py", line 2
#     [t, tt, ttt] *= np.array([1,2,3])
#     ^
# SyntaxError: 'list' is an illegal expression for augmented assignment
